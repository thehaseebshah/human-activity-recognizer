# %%
with open("X_train.txt") as file:
    text = file.readlines()

# %%
text = "\n".join(text)

# %%
text = text.replace("  "," ")

# %%
with open("X_train.txt","w") as file:
    file.write(text)

# %%
import pandas as pd

# %%
data = pd.read_csv("X_train.txt", header=None, sep=" ")

# %%
data
# Out:
#       0         1         2         3         4         5         6    \
# 0     NaN  0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526
# 1     NaN  0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322
# 2     NaN  0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944
# 3     NaN  0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675
# 4     NaN  0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482
# ...   ...       ...       ...       ...       ...       ...       ...
# 7347  NaN  0.299665 -0.057193 -0.181233 -0.195387  0.039905  0.077078
# 7348  NaN  0.273853 -0.007749 -0.147468 -0.235309  0.004816  0.059280
# 7349  NaN  0.273387 -0.017011 -0.045022 -0.218218 -0.103822  0.274533
# 7350  NaN  0.289654 -0.018843 -0.158281 -0.219139 -0.111412  0.268893
# 7351  NaN  0.351503 -0.012423 -0.203867 -0.269270 -0.087212  0.177404
#
#            7         8         9    ...       552       553       554  \
# ...

# %%
with open("features.txt") as file:
    columns = file.readlines()

# %%
df = data.dropna(axis=1)

# %%
df
# Out:
#            1         2         3         4         5         6         7    \
# 0     0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1     0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2     0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3     0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4     0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
# ...        ...       ...       ...       ...       ...       ...       ...
# 7347  0.299665 -0.057193 -0.181233 -0.195387  0.039905  0.077078 -0.282301
# 7348  0.273853 -0.007749 -0.147468 -0.235309  0.004816  0.059280 -0.322552
# 7349  0.273387 -0.017011 -0.045022 -0.218218 -0.103822  0.274533 -0.304515
# 7350  0.289654 -0.018843 -0.158281 -0.219139 -0.111412  0.268893 -0.310487
# 7351  0.351503 -0.012423 -0.203867 -0.269270 -0.087212  0.177404 -0.377404
#
# ...

# %%
cols = []
for c in columns:
    cols.append(c.strip("\n"))

# %%
df.columns = cols

# %%
labels = pd.read_csv("y_train.txt")

# %%
labels = labels.to_numpy()

# %%
x_train = df.to_numpy()

# %%
y_train = labels

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
import numpy as np

# %%
model.fit(x_train[0:7351], np.squeeze(y_train))
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
x_train.shape
# Out:
# (7352, 561)

# %%
y_train.shape
# Out:
# (7351, 1)

# %%
df
# Out:
#       1 tBodyAcc-mean()-X  2 tBodyAcc-mean()-Y  3 tBodyAcc-mean()-Z  \
# 0                0.288585            -0.020294            -0.132905
# 1                0.278419            -0.016411            -0.123520
# 2                0.279653            -0.019467            -0.113462
# 3                0.279174            -0.026201            -0.123283
# 4                0.276629            -0.016570            -0.115362
# ...                   ...                  ...                  ...
# 7347             0.299665            -0.057193            -0.181233
# 7348             0.273853            -0.007749            -0.147468
# 7349             0.273387            -0.017011            -0.045022
# 7350             0.289654            -0.018843            -0.158281
# 7351             0.351503            -0.012423            -0.203867
#
#       4 tBodyAcc-std()-X  5 tBodyAcc-std()-Y  6 tBodyAcc-std()-Z  \
# 0              -0.995279           -0.983111           -0.913526
# ...

# %%
data.shape
# Out:
# (7352, 562)

# %%
labels.shape
# Out:
# (7351, 1)

# %%
# Out:
#        0            1            2            3            4            5    \
# count  0.0  7352.000000  7352.000000  7352.000000  7352.000000  7352.000000
# mean   NaN     0.274488    -0.017695    -0.109141    -0.605438    -0.510938
# std    NaN     0.070261     0.040811     0.056635     0.448734     0.502645
# min    NaN    -1.000000    -1.000000    -1.000000    -1.000000    -0.999873
# 25%    NaN     0.262975    -0.024863    -0.120993    -0.992754    -0.978129
# 50%    NaN     0.277193    -0.017219    -0.108676    -0.946196    -0.851897
# 75%    NaN     0.288461    -0.010783    -0.097794    -0.242813    -0.034231
# max    NaN     1.000000     1.000000     1.000000     1.000000     0.916238
#
#                6            7            8            9    ...          552  \
# count  7352.000000  7352.000000  7352.000000  7352.000000  ...  7352.000000
# mean     -0.604754    -0.630512    -0.526907    -0.606150  ...     0.125293
# ...

# %%
with open("X_test.txt") as file:
    text = file.readlines()

# %%
text = "\n".join(text)

# %%
text = text.replace("  "," ")

# %%
with open("X_test.txt","w") as file:
    file.write(text)

# %%
data = pd.read_csv("X_train.txt", header=None, sep=" ")

# %%
labels = pd.read_csv("y_test.txt")

# %%
labels = labels.to_numpy()

# %%
x_test = data.dropna(axis=1).to_numpy()

# %%
y_test = labels

# %%
x_test = x_test[:2946]

# %%
y_test.shape
# Out:
# (2946, 1)

# %%
x_test.shape
# Out:
# (2946, 561)

# %%
model.score(x_test, np.squeeze(y_test))
# Out:
# 0.9164969450101833

# %%
import joblib

# %%
model
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
joblib.dump(model,"./model.sav")
# Out:
# ['./model.sav']
